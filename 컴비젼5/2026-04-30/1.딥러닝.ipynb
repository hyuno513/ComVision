# %%
# 딥러닝 Deep Learning

# 1. 딥러닝의 정의
# 2010년대 초까지 머신러닝의 주류를 이뤘던 것은 통계학 기반의 분류, 회귀 및 군집 모델이었음
# 특히 분류나 회귀와 같은 지도학습에서 기존의 머신러닝은 학습 데이터의 특성(문제)과
# 이러한 특성을 기반으로 새로운 데이터를 구별하는 학습 모델(답)을 사람이 사전에 정의해야 함
# 그러나 딥러닝은 이러한 것들을 컴퓨터가 스스로 할 수 있게 함
# 예를 들어, 붓꽃의 종을 구별하는 태스크가 있다고 했을 때
# 머신러닝은 사람이 붓꽃의 특성들을 정의하고 데이터세트를 만들고 나서 컴퓨터가 데이터 세트를 기반으로
# 붓꽃을 구별하는 판별식을 결정하는 방법
# 딥러닝은 알고리즘에 의해 컴퓨터가 붓꽃의 사진을 보고 스스로 특성을 찾아내고 판별해 내는 방법


# (CNN)합성곱 신경망 -> 이미지 인식
# 풀링 계층
# 자연어 처리 RNN(순환신경망)

# %%
# 딥러닝에서 깊이, 즉 층의 개수는 은닉층 hidden layer 개수에 하나는 더 하면 됨
# 은닉층은 입력층과 출력층 사이에 있는 층을 말함
# 이러한 이유로 딥러닝을 심층신경망 DNN : Deep Neural Network 라고도 함

# 뉴런에 해당하는 신경망 계층의 각 노드들은 매우 단순한 기능을 함
# 따라서 몇 개의 신경망으로 이뤄진 쉘로우 러닝은 적용범위가 매우 제한적
# 결국 더 복잡한 문제를 풀기 위해서는 긴경망의 계층 수를 늘이고 뉴런과 연결되는 가지 branch의 수도 많아야 함
# 고등동물의 뉴런이 하등동물의 그것보다 많은 것과 같은 논리
# 그러나 딥러닝의 신경망 계층 수를 늘리면 연산에 필요한 복잡도가 제곱 크기로 늘어남
# 당연히 컴퓨터의 계산량도 이에 비례해서 많아짐
# 문제의 크기에 따라 현재 사용하고 있는 컴퓨터로 아예 계산을 못할 수도 있음
# 그럼에도 신경망의 깊이를 늘릴 수 밖에 없는 이유를 3가지로 요약

# %%
# 첫째, 머신러닝이나 쉘로우 러닝으로는 풀지 못했던 어려운 문제를 딥러닝은 풀 수 있음
# 기하학에서 직선으로 표현하지 못하는 것을 곡선의 조합으로 표현할 수 있는 것과 유사

# 둘째, 딥러닝이 모방하고 있는 뇌의 구조 자체가 딥 아키텍처
# 뇌신경 분야 중 비교적 잘 정리되니 시각 피질 visual cortex 관련 연구를 보면 처음 입력된 빛의 신호가
# 무수히 많은 뉴런을 거쳐 형상화 됨

# 셋째, 동물이나 사람이 인지하는 처리 절차가 여러 계층으로 체계화 되어 있음
# 예를 들면, 먼저 학습한 간단한 개념을 가지고 다양하게 조합하면서 더 복잡한 개념을 추상화

# %%
# 3. 딥러닝의 미래 : 인공지능의 핵심 기술
# 2010년대에 들어서면서 딥러닝이 급속도로 발전한 배경에는 혁신적인 알고리즘의 개발과 더불어
# 컴퓨터 하드웨어의 발전도 큰 몫을 차지
# 컴퓨터의 중앙처리장치인 cpu는 2년에 두 배씩 빨라지고 있으며
# 메모리 용량은 매년 두 배로 커지고 있음
# 더욱 저렴한 가격으로 보급되는 컴퓨터를 네트워크로 연결해 누구나 고성능의 슈퍼컴퓨터를 만들어 사용할 수 있게 됨

# 최근에는 딥러닝 알고리즘에 GPU Graphic Processing Unit (실리콘칩 안에 몇천 갱의 연산자가 이미지 처리를 병렬로 수행)
# 기반의 프로그래밍 기법이 등장하면서 획기적인 성능 향상을 가져옴
# 2000년대 초반에 컴볼루션 신명망 CNN의 선구자인 얀 르쿤은 인공신경망에 적용된 GPU의 성능이 CPU보다 약 100배 빠른
# 연구 결과를 확인하면서 딥러닝에서 GPU의 역할을 주목하기 시작

# 컴퓨터 그래픽 분야에서 단순한 이미지 처리용으로 사용됐던 GPU가 숫자 연산 집약적인 범용 프로세서로 재탄생하면서
# 딥러닝이 핵심적인 역할을 하기 시작
# 예를 들면, 2006년에 첼라필라와 그 동료들은 GPU를 이용해 필기체를 분석하는 연구를 통해 CPU만 사용했을 때보다 4배 이상의 성능향상을 보임

# %%
# 2012년 구글은 구글 브레인이라는 프로젝트에 16,000개의 서버로 구성된 디지털 브레인을
# 3일 동안 1,000만개의 이미지를 교육시킨 후 임의의 사진 속에서 고양이를 찾아내는 데 성공
# 구글의 디지털 브레인을 만들기 위해 구글이 사용한 컴퓨터에는 일반 CPU만 정착된 것으로 17억 개의 신경망과 같은
# 기능을 할 수 있는 시스템

# 구글 브레인 프로젝트가 성공적으로 끝나고 1년 뒤에 바이두의 인공지능 연구소 수석과학자인 엔두류 응은
# 구글 브레인과 동일한 성능을 단 3대의 컴퓨터로 해결
# 바이두의 시스템과 구글 브레인의 유일한 차이점은 GPU의 사용 여부
# 바이두는 여기서 더 나아가 서버를 16대로 확장하고 112억 개의 신경망을 가진 디지털 브레인을 구축
# 바이두는 이 디지털 브레인을 컴퓨터 비전, 음성인식, 자연어 처리 등의 분야에 사용

# %%
# 세기의 대결의 승자 알파고도 GPU를 사용
# 알파고 두뇌는 176개의 GPU와 1,202개의 일반 CPU로 구성
# 알파고의 두뇌는 물리적으로 미국 실리콘벨리에 있는 구글 데이터센터에 위치해 있고,
# 알파고를 설계한 팀은 연구에 있는 구글 딥마인드이지만 GPU를 이용해 대규모 연산을 지원하는 시스템을 구축하는 데는
# 실리콘벨리에 있는 구글 본사의 엔지니어가 협업했을 가능성이 높음

# GPU가 인공지능, 특히 딥러닝에서 각광받는 이유는 무엇일까?
# 어떤 관점에서는 GPU가 CPU보다 우리의 두뇌를 더 닮았다고 볼 수 있음
# 인간의 대뇌 피질에 잇는 약 100억 개의 뉴런은 매우 간단한 기능을 수행
# 간단한 기능을 하는 무수히 많은 뉴런들이 시냅스로 연결되어 감각세포가 감지한 외부 작을 여러 단계의 처리 과정을 거쳐 정보화
# 산술적인 성능 향상이 실제로 가능한 이유는 딥러닝에서 차지하는 대부분의 컴퓨터 과정은
# 행렬과 행렬, 행렬과 벡터의 단순 반복 계산으로 이루어져 있음
